# %%
import pandas as pd
# !pip3 install pandas

# %%
#This is a basketball team from ST Johns University

basketball={'Full Name':['Cruz Davis','Sadiku Ibine Ayo','Jordan Dingle','Nahiem Alleyne','Daniss Jenkins','Simeon Wilcher','Chris Ledlum','Joel Soriano','RJ Luis','Zuby Ejiofor','Sean Conway','Gllenn Taylor Jr.','Brady Dunlap','Drissa Traore','Kenneth Hayes'],
            'Weights'   :[172,205,196,200,180,180,225,255,196,237,200,205,190,215,180],
            'GPA'   :[3.5,3.0,3.4,3.0,3.6,3.3,4.0,3.1,3.7,3.2,3.8,3.2,2.5,2.7,3.1],
            'Jersey'   :[0,2,3,4,5,7,8,11,18,21,24,30,35,44,55]
           }

#This creates a data frame out of the roster that we gave
basketball_df = pd.DataFrame(basketball)

basketball_df
# Out:
#             Full Name  Weights  GPA  Jersey
# 0          Cruz Davis      172  3.5       0
# 1    Sadiku Ibine Ayo      205  3.0       2
# 2       Jordan Dingle      196  3.4       3
# 3      Nahiem Alleyne      200  3.0       4
# 4      Daniss Jenkins      180  3.6       5
# 5      Simeon Wilcher      180  3.3       7
# 6        Chris Ledlum      225  4.0       8
# 7        Joel Soriano      255  3.1      11
# 8             RJ Luis      196  3.7      18
# 9        Zuby Ejiofor      237  3.2      21
# 10        Sean Conway      200  3.8      24
# 11  Gllenn Taylor Jr.      205  3.2      30
# 12       Brady Dunlap      190  2.5      35
# 13      Drissa Traore      215  2.7      44
# 14      Kenneth Hayes      180  3.1      55

# %%
#This returns a numerical breakdown of the statisitcs of the dataset

basketball_df.describe()
# Out:
#           Weights        GPA     Jersey
# count   15.000000  15.000000  15.000000
# mean   202.400000   3.273333  17.800000
# std     22.871692   0.406143  16.823453
# min    172.000000   2.500000   0.000000
# 25%    185.000000   3.050000   4.500000
# 50%    200.000000   3.200000  11.000000
# 75%    210.000000   3.550000  27.000000
# max    255.000000   4.000000  55.000000
